# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2', index_col=0)

# %%
df2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
# You can call a plot directly off of a dataframe in matplotlib
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
# Another way to call a plot
df1['A'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: xlabel='a'>

# %%
df2.plot.bar(stacked = True)
# Out:
# <Axes: xlabel='a'>

# %%
df1['A'].plot.hist(bins= 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B', lw=1 )
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'] * 100,cmap='magma')
# Out:
# /Users/btodd/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /Users/btodd/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a', y='b', gridsize=27,cmap='magma')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
# You could also do this off of the whole data frame. It does not have to be just one column
# df.plot.density()
df2['b'].plot.density()
# Out:
# <Axes: ylabel='Density'>
